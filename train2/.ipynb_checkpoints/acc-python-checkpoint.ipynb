# %%
# pwd

# %%
#  cd '/Users/vaishalilalit/Masters in Artificial Intelligence/Projects/ucc/challenge phase/'

# %%
# ls

# %%
# import os
# import cv2
# import matplotlib.pyplot as plt
# import numpy as np
# input_dir = './ann/train'
# output_dir = './labels/train'

# for j in os.listdir(input_dir):
#     image_path = os.path.join(input_dir, j)

#     # load the binary mask and get its contours
#     mask = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
# #     plt.imshow(mask)
    
# #     _, mask = cv2.threshold(mask, 1, 255, cv2.THRESH_BINARY)
#     H, W = mask.shape
#     plt.imshow(mask)
#     contours, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     contour_image = np.zeros_like(mask)
#     for idx, cnt in enumerate(contours):
#         print(f"Contour {idx + 1} - Area: {cv2.contourArea(cnt)}")

# #     print(f"Number of contours found: {len(contours)}")

#     # draw contours on the blank image
#     cv2.drawContours(contour_image, contours, -1, (255), 2)
   
#     # visualize the contours
#     plt.imshow(contour_image, cmap='gray')
#     plt.title('Contours')
#     plt.show()
#     # convert the contours to polygons
#     polygons = []
#     for cnt in contours:
#         if cv2.contourArea(cnt) > 200:
#             polygon = []
#             for point in cnt:
#                 x, y = point[0]
#                 polygon.append(x / W)
#                 polygon.append(y / H)
#             polygons.append(polygon)
# #     print(f"Polygon {idx + 1}: {polygon}")
#     # print the polygons
#     with open('{}.txt'.format(os.path.join(output_dir, j)[:-4]), 'w') as f:
#         for polygon in polygons:
#             for p_, p in enumerate(polygon):
#                 if p_ == len(polygon) - 1:
#                     f.write('{}\n'.format(p))
#                 elif p_ == 0:
#                     f.write('0 {} '.format(p))
#                 else:
#                     f.write('{} '.format(p))

#         f.close()

# %%
cd '/Users/vaishalilalit/Downloads'
# Out:
# /Users/vaishalilalit/Downloads

# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (8.1.9)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: numpy>=1.22.2 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.24.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.11.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (8.0.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.7.1)
# Requirement already satisfied: sympy in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/vaishalilalit/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
pwd
# Out:
# '/Users/vaishalilalit/Downloads'

# %%
# cd '/train2/Mynewtest/'

# %%
# cv2.imread('/Users/vaishalilalit/Downloads/train2/test/00a3aa6a5bded1cf0edfa98bca6a8696.jpg')

# %%
from ultralytics import YOLO
import cv2
import os
import matplotlib.pyplot as plt
model_path='/Users/vaishalilalit/Downloads//train/weights/best.pt'
input_dir='/Users/vaishalilalit/Downloads/train/test/test'
output_dir='/Users/vaishalilalit/Downloads/train/test/mask'
for j in os.listdir(input_dir):
    image_path = os.path.join(input_dir, j)
    image=cv2.imread(image_path)
#     plt.imshow( image)
    H,W,_=image.shape
    model=YOLO(model_path)
    results=model(image)
    base_filename = os.path.splitext(j)[0]  # Extracting the base filename without extension

    for i, result in enumerate(results):
        if result.masks is not None and hasattr(result.masks, 'data'):
            for k, mask in enumerate(result.masks.data):
                mask = mask.numpy() * 255
                mask = cv2.resize(mask, (W, H)).astype('uint8')

                # Save the mask with the original filename and an index
                mask_filename = '{}.jpg'.format(base_filename)
                mask_filepath = os.path.join(output_dir, mask_filename)
                cv2.imwrite(mask_filepath, mask)
                print(f"Saved mask at: {mask_filepath}")
        else:
            print(f"No masks found for: {os.path.join(output_dir, j)}")
# Out:
# 0: 416x512 1 high vegetation, 120.4ms
# Speed: 12.2ms preprocess, 120.4ms inference, 27.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/66c81e5938d8648934776ed8fa2fdf1f.jpg
#
# 0: 416x512 3 high vegetations, 53.0ms
# Speed: 1.1ms preprocess, 53.0ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7c92109e1bf8758084e4a50700327254.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7c92109e1bf8758084e4a50700327254.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7c92109e1bf8758084e4a50700327254.jpg
#
# 0: 448x512 (no detections), 69.2ms
# Speed: 1.7ms preprocess, 69.2ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/3ec60e6b8b3f48261966e7ca6881195d.jpg
#
# 0: 256x512 (no detections), 39.1ms
# Speed: 1.1ms preprocess, 39.1ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/b6b18e022c136c239887b31eccb4f52c.jpg
#
# 0: 416x512 1 high vegetation, 56.1ms
# Speed: 1.3ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e053657f245a221720708e2399a9f497.jpg
#
# 0: 448x512 1 high vegetation, 78.9ms
# Speed: 1.3ms preprocess, 78.9ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1202e45c94e2884b719a261e0075dfa2.jpg
#
# 0: 384x512 1 high vegetation, 60.1ms
# Speed: 1.2ms preprocess, 60.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6a8de8c8938805cc879ddfb045da07a4.jpg
#
# 0: 416x512 1 high vegetation, 57.8ms
# Speed: 1.4ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/75ddeb10d253fbf6db80050570d534a0.jpg
#
# 0: 448x512 4 high vegetations, 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0da29af0789c81d831532dd1cad38603.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0da29af0789c81d831532dd1cad38603.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0da29af0789c81d831532dd1cad38603.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0da29af0789c81d831532dd1cad38603.jpg
#
# 0: 480x512 1 high vegetation, 62.6ms
# Speed: 1.3ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c945363bdd37a23d58f457b4a571f859.jpg
#
# 0: 416x512 1 high vegetation, 60.8ms
# Speed: 1.1ms preprocess, 60.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e1ded7e9d9ab2d296bb0db4837f31e32.jpg
#
# 0: 448x512 1 high vegetation, 62.8ms
# Speed: 1.1ms preprocess, 62.8ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/4d9657fa3ddd80aa4208b596ab999856.jpg
#
# 0: 512x512 1 high vegetation, 77.2ms
# Speed: 1.4ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/15faf93f5b819652d49061cde6166c71.jpg
#
# 0: 416x512 1 high vegetation, 58.0ms
# Speed: 1.3ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a1512163ff933f1b4f25be0e5323ccb4.jpg
#
# 0: 384x512 1 high vegetation, 56.5ms
# Speed: 1.1ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/60c66676ed2b2dcf947bbe76825900d3.jpg
#
# 0: 448x512 1 high vegetation, 64.7ms
# Speed: 1.3ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0417c2260695d0cf35b77cb68c2f0300.jpg
#
# 0: 352x512 1 high vegetation, 61.9ms
# Speed: 1.3ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/172673c08ab50924abc27c2d1c3f3594.jpg
#
# 0: 512x512 2 high vegetations, 79.3ms
# Speed: 1.5ms preprocess, 79.3ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/4c81cf2f77320351e637fa5c270c57b2.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/4c81cf2f77320351e637fa5c270c57b2.jpg
#
# 0: 512x512 1 high vegetation, 82.1ms
# Speed: 1.9ms preprocess, 82.1ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/8684bf64a18d91ea3c5852a9ee36e3dc.jpg
#
# 0: 288x512 1 high vegetation, 45.9ms
# Speed: 1.1ms preprocess, 45.9ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6d4383c3d7aa69e5ef6ca948b8b25fad.jpg
#
# 0: 512x512 2 high vegetations, 95.6ms
# Speed: 2.1ms preprocess, 95.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/64d4c4ec22df62b10348e9d22927f772.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/64d4c4ec22df62b10348e9d22927f772.jpg
#
# 0: 384x512 1 high vegetation, 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/42259482faecd46a38b680f2e8bb210c.jpg
#
# 0: 480x512 2 high vegetations, 80.5ms
# Speed: 1.6ms preprocess, 80.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/d85c620b7cbdf46208ec768616d96304.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/d85c620b7cbdf46208ec768616d96304.jpg
#
# 0: 480x512 1 high vegetation, 68.4ms
# Speed: 1.6ms preprocess, 68.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/43b4dd750533a0f12bb1d7ec869db6fa.jpg
#
# 0: 448x512 3 high vegetations, 77.3ms
# Speed: 1.7ms preprocess, 77.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/40ab1a7fc40ad7cde759dec44c24b3b6.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/40ab1a7fc40ad7cde759dec44c24b3b6.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/40ab1a7fc40ad7cde759dec44c24b3b6.jpg
#
# 0: 416x512 1 high vegetation, 69.6ms
# Speed: 1.2ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/306b792581c32f47bae1913f38febcc4.jpg
#
# 0: 352x512 1 high vegetation, 55.7ms
# Speed: 1.3ms preprocess, 55.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/3b34bf2ed0261ef98636edf330470dc5.jpg
#
# 0: 416x512 1 high vegetation, 60.7ms
# Speed: 1.3ms preprocess, 60.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/99c911e6252bb7a2cba7899d14ad976a.jpg
#
# 0: 512x512 1 high vegetation, 75.3ms
# Speed: 1.3ms preprocess, 75.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/3974ba4f00712990fcca69f90091b420.jpg
#
# 0: 512x512 1 high vegetation, 68.6ms
# Speed: 1.3ms preprocess, 68.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b876ed1a91907cdfb204dc6af6465ff4.jpg
#
# 0: 512x512 1 high vegetation, 69.0ms
# Speed: 1.3ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/75d9add379a0ae3584b053a14b2bd50b.jpg
# 0: 512x512 1 high vegetation, 70.9ms
# Speed: 1.4ms preprocess, 70.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/242527d64455f51ffe9eabe24651b090.jpg
#
# 0: 512x512 1 high vegetation, 86.6ms
# Speed: 1.7ms preprocess, 86.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/9c474ffb95de79e41994c45ec5e97183.jpg
#
# 0: 416x512 1 high vegetation, 64.3ms
# Speed: 1.6ms preprocess, 64.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f6ebc335c4aa8df7e2850de6963ba395.jpg
#
# 0: 512x512 1 high vegetation, 85.9ms
# Speed: 1.5ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c34de6669a087ace3e75ea9d7172f4e1.jpg
#
# 0: 384x512 1 high vegetation, 56.8ms
# Speed: 1.3ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/747fdded643779e8e08d0ff1d37f76fe.jpg
#
# 0: 512x512 1 high vegetation, 71.9ms
# Speed: 1.3ms preprocess, 71.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/d177db66ba90f6e2005fd306aef82496.jpg
#
# 0: 256x512 2 high vegetations, 38.5ms
# Speed: 0.8ms preprocess, 38.5ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/259e4c9c05b57038ae92332c569cba8f.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/259e4c9c05b57038ae92332c569cba8f.jpg
#
# 0: 416x512 2 high vegetations, 57.1ms
# Speed: 1.2ms preprocess, 57.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/afed792289820833b84d34fa4d10bbf9.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/afed792289820833b84d34fa4d10bbf9.jpg
#
# 0: 416x512 2 high vegetations, 58.1ms
# Speed: 1.6ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6174f19387c37f6d3d3a12172f839afb.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6174f19387c37f6d3d3a12172f839afb.jpg
#
# 0: 352x512 1 high vegetation, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/9121454ad5bf94f3f31028500908fb78.jpg
#
# 0: 416x512 2 high vegetations, 60.8ms
# Speed: 1.3ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/982e0b385c2245c1b995f3dfdd6aed1f.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/982e0b385c2245c1b995f3dfdd6aed1f.jpg
#
# 0: 448x512 1 high vegetation, 60.2ms
# Speed: 1.1ms preprocess, 60.2ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/3575de2b62ef2784f22ef865a52363fe.jpg
#
# 0: 448x512 2 high vegetations, 62.4ms
# Speed: 1.1ms preprocess, 62.4ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/3abe45b5da690a1d74a7ed30d9ad9e39.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/3abe45b5da690a1d74a7ed30d9ad9e39.jpg
#
# 0: 384x512 1 high vegetation, 61.5ms
# Speed: 1.0ms preprocess, 61.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/5739edb26da53c88752faced7913f8cd.jpg
#
# 0: 416x512 1 high vegetation, 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ae5b59292a3d1d154ad03815e9f647f6.jpg
#
# 0: 416x512 1 high vegetation, 56.3ms
# Speed: 1.1ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e85126291a8cf73a75dcddb30a40b31a.jpg
#
# 0: 416x512 1 high vegetation, 52.1ms
# Speed: 1.2ms preprocess, 52.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/719a6972b0d2fc5494f9a290a4b6e5cb.jpg
#
# 0: 320x512 1 high vegetation, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6119310e31fe2e402c9814dc48d527ab.jpg
#
# 0: 480x512 2 high vegetations, 61.9ms
# Speed: 1.6ms preprocess, 61.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c129a9e4902c9c4e3517bf27a2bf160a.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c129a9e4902c9c4e3517bf27a2bf160a.jpg
#
# 0: 448x512 1 high vegetation, 64.6ms
# Speed: 1.3ms preprocess, 64.6ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0d6aa7008df89fc682a8e2e3a8a3e4e7.jpg
#
# 0: 512x512 1 high vegetation, 69.1ms
# Speed: 1.3ms preprocess, 69.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a4b8d0fe488d00ae3d116160b434d482.jpg
#
# 0: 416x512 1 high vegetation, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7b2b364ba8484393c0c24baae9aca9e4.jpg
#
# 0: 448x512 1 high vegetation, 59.3ms
# Speed: 1.4ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/96f8105c32d943505e893c04766ca930.jpg
#
# 0: 384x512 1 high vegetation, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/281ca5a7fc0a55ec814cab3cd6846fb3.jpg
#
# 0: 352x512 2 high vegetations, 54.2ms
# Speed: 1.1ms preprocess, 54.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6a64e958d7e8a73de0d52a6118c7c90b.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6a64e958d7e8a73de0d52a6118c7c90b.jpg
#
# 0: 416x512 2 high vegetations, 61.1ms
# Speed: 1.1ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0ca2488de0f06078c47ae5d5eaa90093.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0ca2488de0f06078c47ae5d5eaa90093.jpg
#
# 0: 480x512 2 high vegetations, 71.3ms
# Speed: 1.4ms preprocess, 71.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/2d12b5be39d5c43b489fda87389c31f0.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/2d12b5be39d5c43b489fda87389c31f0.jpg
#
# 0: 448x512 2 high vegetations, 76.2ms
# Speed: 1.3ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c68ba21dae599ddaf2d37223da4f8136.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c68ba21dae599ddaf2d37223da4f8136.jpg
#
# 0: 448x512 1 high vegetation, 68.4ms
# Speed: 1.2ms preprocess, 68.4ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/371d55d1ac62e00ec69e9aa04d98b44f.jpg
#
# 0: 416x512 1 high vegetation, 62.8ms
# Speed: 1.4ms preprocess, 62.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/646a72e01a29b53c5e693fb0738e1cfb.jpg
#
# 0: 416x512 1 high vegetation, 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1ac29b41599b0a1cb28fb90b1f078aee.jpg
# 0: 352x512 2 high vegetations, 55.9ms
# Speed: 1.2ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bff3d473f176e4e7761936024c615e43.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bff3d473f176e4e7761936024c615e43.jpg
#
# 0: 480x512 1 high vegetation, 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/246ca7ca1a5b1469aa7b0748a99d1c1f.jpg
#
# 0: 352x512 1 high vegetation, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b0fceb209314369e8c0f6393b5b1dca8.jpg
#
# 0: 448x512 1 high vegetation, 58.8ms
# Speed: 1.5ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/5b66f4c384dbbda608e149ed8d875b28.jpg
#
# 0: 512x512 1 high vegetation, 76.4ms
# Speed: 1.4ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7ec660b097cc74ec5453517fb9b4b165.jpg
#
# 0: 480x512 1 high vegetation, 67.3ms
# Speed: 1.3ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a187900063fb7a1fc773cc09816ff7fe.jpg
#
# 0: 416x512 1 high vegetation, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/420cee943db60b7f89e00b62db80dbd5.jpg
#
# 0: 416x512 2 high vegetations, 57.5ms
# Speed: 1.3ms preprocess, 57.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/06df3d01a11b40caf3f433b7fc8b7d07.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/06df3d01a11b40caf3f433b7fc8b7d07.jpg
#
# 0: 480x512 1 high vegetation, 65.0ms
# Speed: 1.5ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/99d85acaebb8d17c4d716c91d9c6bec0.jpg
#
# 0: 384x512 1 high vegetation, 58.5ms
# Speed: 0.8ms preprocess, 58.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/8c372c36900ea07613a3d50c8d57a71d.jpg
#
# 0: 416x512 2 high vegetations, 64.8ms
# Speed: 1.3ms preprocess, 64.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bc29a9e6569576026735a8d3cdfeeaed.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bc29a9e6569576026735a8d3cdfeeaed.jpg
#
# 0: 416x512 1 high vegetation, 67.2ms
# Speed: 1.3ms preprocess, 67.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7673ae00320f2b0eb678f0c34aca4d44.jpg
#
# 0: 416x512 1 high vegetation, 65.9ms
# Speed: 1.6ms preprocess, 65.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/9d315a394d5db0c2b852e4f257d2ee43.jpg
#
# 0: 224x512 1 high vegetation, 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f4b0fe50be0f6f2d9e992090c7518212.jpg
#
# 0: 384x512 1 high vegetation, 67.4ms
# Speed: 1.1ms preprocess, 67.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/75b18aabca731d6857afd69d8b038e48.jpg
#
# 0: 384x512 1 high vegetation, 63.9ms
# Speed: 1.2ms preprocess, 63.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/91adbd96769b122a99cd65bbaff89782.jpg
#
# 0: 480x512 1 high vegetation, 68.3ms
# Speed: 1.2ms preprocess, 68.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/afd683c8accf7d9bff4533de67ac30db.jpg
#
# 0: 512x512 1 high vegetation, 79.1ms
# Speed: 1.3ms preprocess, 79.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c4f0ccede364df3d632727edb67ee8ac.jpg
#
# 0: 384x512 2 high vegetations, 63.3ms
# Speed: 1.4ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/392f3493e17148eef7d7f074e291bf05.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/392f3493e17148eef7d7f074e291bf05.jpg
#
# 0: 480x512 1 high vegetation, 72.8ms
# Speed: 1.3ms preprocess, 72.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c87ce703ec9fc2f5f10f2dd60294c718.jpg
#
# 0: 416x512 1 high vegetation, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c9fcbc4d625ecbc7267009526e2d2204.jpg
#
# 0: 416x512 2 high vegetations, 60.5ms
# Speed: 1.2ms preprocess, 60.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0944750a241aa6d9f3be0b34fa5b078a.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0944750a241aa6d9f3be0b34fa5b078a.jpg
#
# 0: 448x512 1 high vegetation, 65.7ms
# Speed: 1.2ms preprocess, 65.7ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/29a15a1330b9681b5ac422d9e05807c8.jpg
#
# 0: 512x512 1 high vegetation, 75.0ms
# Speed: 1.4ms preprocess, 75.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/5ae57c97c2dea194931959efc6f0de7d.jpg
#
# 0: 448x512 1 high vegetation, 65.5ms
# Speed: 1.1ms preprocess, 65.5ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/5ff15b4c561f36cdeecb9ba286d53577.jpg
#
# 0: 384x512 1 high vegetation, 58.6ms
# Speed: 1.6ms preprocess, 58.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/d31f7232bbe32180af38ad1c1942e18f.jpg
#
# 0: 480x512 2 high vegetations, 69.3ms
# Speed: 1.4ms preprocess, 69.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6cd228813f8e269f7ab43884612cf532.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6cd228813f8e269f7ab43884612cf532.jpg
#
# 0: 448x512 1 high vegetation, 66.0ms
# Speed: 1.7ms preprocess, 66.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/4aeac1b347ffbd8035675a0bb3370e34.jpg
#
# 0: 480x512 2 high vegetations, 65.9ms
# Speed: 1.5ms preprocess, 65.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0873a68a8f766db67ba174d26cac3f8a.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0873a68a8f766db67ba174d26cac3f8a.jpg
#
# 0: 480x512 1 high vegetation, 77.8ms
# Speed: 1.5ms preprocess, 77.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f810c027c51c09f12da74aaa3ce2e8c8.jpg
#
# 0: 320x512 1 high vegetation, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f9aa1543b113a5ac0367914e44043cd8.jpg
#
# 0: 320x512 2 high vegetations, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ea04eb6d88bc0d26f314786082b6c3b3.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ea04eb6d88bc0d26f314786082b6c3b3.jpg
# 0: 416x512 1 high vegetation, 60.8ms
# Speed: 1.4ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e23d5cc30c5a5af722bf8859138c27c4.jpg
#
# 0: 416x512 1 high vegetation, 58.1ms
# Speed: 1.2ms preprocess, 58.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b8094c9fae0692c0a77f479680f1abfe.jpg
#
# 0: 352x512 2 high vegetations, 47.9ms
# Speed: 1.0ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f0be9d6b3023635b5a15574cb6d9558f.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f0be9d6b3023635b5a15574cb6d9558f.jpg
#
# 0: 352x512 1 high vegetation, 48.9ms
# Speed: 1.5ms preprocess, 48.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/21be0c1e0243afbbc7bce65f397442e9.jpg
#
# 0: 512x512 1 high vegetation, 75.2ms
# Speed: 1.5ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/3c7d9a5929b4e6f7e03ee54c4c3c1964.jpg
#
# 0: 448x512 2 high vegetations, 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c5eb77aa77fe43168bc3ea570d648464.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c5eb77aa77fe43168bc3ea570d648464.jpg
#
# 0: 416x512 2 high vegetations, 62.2ms
# Speed: 1.8ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7f9c97ba7b1fc9a50c5e915d104660e7.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7f9c97ba7b1fc9a50c5e915d104660e7.jpg
#
# 0: 352x512 2 high vegetations, 49.1ms
# Speed: 0.9ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/dffbc741e1d76956c349c8721aef8bb6.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/dffbc741e1d76956c349c8721aef8bb6.jpg
#
# 0: 384x512 1 high vegetation, 53.8ms
# Speed: 1.0ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1f134a0905ab9f3bfbd7e9d5c6e0a36b.jpg
#
# 0: 320x512 1 high vegetation, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6c66c248f0908db77fcf3822bc5efa5b.jpg
#
# 0: 416x512 1 high vegetation, 57.9ms
# Speed: 1.3ms preprocess, 57.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ea1069053beb08a70a2a1b40b2c58ad2.jpg
#
# 0: 480x512 1 high vegetation, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a90df8d352dd344c2526b44ddcb4fa10.jpg
#
# 0: 416x512 1 high vegetation, 66.0ms
# Speed: 1.3ms preprocess, 66.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/94833a039390fc39d5dec68324a429d1.jpg
#
# 0: 512x512 1 high vegetation, 76.9ms
# Speed: 1.4ms preprocess, 76.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/240468707ea9e434ecde33e5d0588a92.jpg
#
# 0: 512x512 2 high vegetations, 79.1ms
# Speed: 1.7ms preprocess, 79.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/21ef717cebde1517de7635ef0b8645f5.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/21ef717cebde1517de7635ef0b8645f5.jpg
#
# 0: 416x512 1 high vegetation, 60.4ms
# Speed: 1.3ms preprocess, 60.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/30aae95a8e974f7a1a41ff06b598ff43.jpg
#
# 0: 512x512 1 high vegetation, 82.7ms
# Speed: 1.5ms preprocess, 82.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/aec68f15e6e87b34ab4cdaae24cfaea0.jpg
#
# 0: 448x512 (no detections), 76.9ms
# Speed: 1.4ms preprocess, 76.9ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/0baec17c62666d572fe5d2c047d058fe.jpg
#
# 0: 512x512 1 high vegetation, 71.7ms
# Speed: 1.2ms preprocess, 71.7ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/def24f5d15a9a49faa6e642bbf523512.jpg
#
# 0: 512x512 2 high vegetations, 76.9ms
# Speed: 1.4ms preprocess, 76.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a179fa6ee3e1a40b1a3fda627706db08.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a179fa6ee3e1a40b1a3fda627706db08.jpg
#
# 0: 480x512 1 high vegetation, 64.6ms
# Speed: 1.2ms preprocess, 64.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/39deaf147da39f8e47282e2fc6bcbc4d.jpg
#
# 0: 416x512 2 high vegetations, 62.5ms
# Speed: 1.4ms preprocess, 62.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/4465ba96d26977716d08914f147103b9.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/4465ba96d26977716d08914f147103b9.jpg
#
# 0: 448x512 1 high vegetation, 63.4ms
# Speed: 1.7ms preprocess, 63.4ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f0a1486bbafe4422e686c4bcacca7c42.jpg
#
# 0: 448x512 1 high vegetation, 62.6ms
# Speed: 1.2ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e9a94526aa555d1ae1c4f711a3261b06.jpg
#
# 0: 512x512 2 high vegetations, 71.1ms
# Speed: 1.3ms preprocess, 71.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0c51a565f4c9167be58e4b941623aa50.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0c51a565f4c9167be58e4b941623aa50.jpg
#
# 0: 448x512 1 high vegetation, 208.2ms
# Speed: 1.2ms preprocess, 208.2ms inference, 4.1ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a938f64d4cdd2668ecec9c9125646afc.jpg
#
# 0: 352x512 1 high vegetation, 60.3ms
# Speed: 1.5ms preprocess, 60.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bfcb9d93e7b8f6f2d27b8bcdbf7c60f2.jpg
#
# 0: 352x512 1 high vegetation, 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/95f15910adfc02018f2c3a7eaf2283ee.jpg
#
# 0: 416x512 2 high vegetations, 56.0ms
# Speed: 1.4ms preprocess, 56.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/25302695ca29921f3a0c82005d9163ec.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/25302695ca29921f3a0c82005d9163ec.jpg
#
# 0: 416x512 2 high vegetations, 54.7ms
# Speed: 1.3ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/962298e50c0089331a0214a40517b9a3.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/962298e50c0089331a0214a40517b9a3.jpg
#
# 0: 512x512 1 high vegetation, 74.9ms
# Speed: 1.4ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/edb9dc472ac72c241a7d5095dc3a9ff7.jpg
# 0: 480x512 1 high vegetation, 69.2ms
# Speed: 1.2ms preprocess, 69.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b01b6b6d81871b66707d05f1cde93770.jpg
#
# 0: 416x512 (no detections), 54.0ms
# Speed: 1.3ms preprocess, 54.0ms inference, 0.1ms postprocess per image at shape (1, 3, 416, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/5e15ceb87b534a7773919566a6674fa3.jpg
#
# 0: 416x512 1 high vegetation, 55.1ms
# Speed: 1.2ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6da590a7e8b451d7cee1f5a391090c44.jpg
#
# 0: 512x512 1 high vegetation, 74.6ms
# Speed: 1.3ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bb3184e0f1d46c142d785e19b21b7fbe.jpg
#
# 0: 448x512 (no detections), 68.2ms
# Speed: 1.2ms preprocess, 68.2ms inference, 0.1ms postprocess per image at shape (1, 3, 448, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/12b0f4865049468d027314c06ce49ff3.jpg
#
# 0: 448x512 1 high vegetation, 59.9ms
# Speed: 1.4ms preprocess, 59.9ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7a334e729918e37a0b921c9543d9f82d.jpg
#
# 0: 416x512 1 high vegetation, 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f39546faf341a83f9aeebc7269d3f8b1.jpg
#
# 0: 448x512 1 high vegetation, 144.8ms
# Speed: 1.3ms preprocess, 144.8ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/202098242e5b91907a17aeabe1aec836.jpg
#
# 0: 448x512 1 high vegetation, 61.9ms
# Speed: 1.2ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/cc87a50005fa23059135ba1328ed7d03.jpg
#
# 0: 416x512 1 high vegetation, 56.2ms
# Speed: 1.2ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a1e51488c8ffc8127922f8696d86cdb9.jpg
#
# 0: 480x512 1 high vegetation, 64.8ms
# Speed: 1.7ms preprocess, 64.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/21151cfa2b33620f1681d74b1549432e.jpg
#
# 0: 448x512 2 high vegetations, 59.9ms
# Speed: 1.3ms preprocess, 59.9ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/397695d5c612bd0f940da4a801b26c37.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/397695d5c612bd0f940da4a801b26c37.jpg
#
# 0: 448x512 1 high vegetation, 58.9ms
# Speed: 1.3ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0b4d46bdea2064bcf47a644c73788c5a.jpg
#
# 0: 384x512 1 high vegetation, 54.0ms
# Speed: 1.1ms preprocess, 54.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/02e18b3bc8b045fa5507deebaae5e22d.jpg
#
# 0: 416x512 1 high vegetation, 63.7ms
# Speed: 1.3ms preprocess, 63.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6d4b307718f4bbe1cbbc9ada868c34e6.jpg
#
# 0: 448x512 1 high vegetation, 64.9ms
# Speed: 1.3ms preprocess, 64.9ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bb7c3cf5c5f29f060a8b14594d0cd27c.jpg
#
# 0: 512x512 1 high vegetation, 76.0ms
# Speed: 1.4ms preprocess, 76.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/06e78f5c45edb8b0f39859f1f0622dc4.jpg
#
# 0: 512x512 1 high vegetation, 76.0ms
# Speed: 1.4ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1b0e57f4bb0c03a09347a8c9e5cac337.jpg
#
# 0: 480x512 1 high vegetation, 64.6ms
# Speed: 1.2ms preprocess, 64.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/48ca291920013e45e26cc02ec3d2a753.jpg
#
# 0: 416x512 1 high vegetation, 60.3ms
# Speed: 1.3ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/89141bb4bdd6e1cdfa745491bffdd042.jpg
#
# 0: 480x512 1 high vegetation, 60.2ms
# Speed: 1.4ms preprocess, 60.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/4c577e0e1048cbb255a6229d0fe54c6c.jpg
#
# 0: 352x512 1 high vegetation, 46.9ms
# Speed: 1.0ms preprocess, 46.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/d2505775cce48993168e7e278b81fb8e.jpg
#
# 0: 512x512 (no detections), 70.0ms
# Speed: 1.5ms preprocess, 70.0ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/a9ece6350d46dcb59bc7c78162c4b872.jpg
#
# 0: 448x512 1 high vegetation, 56.5ms
# Speed: 1.3ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c5bbad8dcc894268931cd386abc49460.jpg
#
# 0: 384x512 1 high vegetation, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/21eedf4a24c9324737132750b6ea46f2.jpg
#
# 0: 448x512 1 high vegetation, 55.6ms
# Speed: 1.2ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/90c327d2f61882f4ec8122fd468e6aa2.jpg
#
# 0: 512x512 1 high vegetation, 69.0ms
# Speed: 1.6ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f4db9ed928e24001486160ca9e524c38.jpg
#
# 0: 384x512 5 high vegetations, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/16c9ca229c5ce45fc56655844074b12b.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/16c9ca229c5ce45fc56655844074b12b.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/16c9ca229c5ce45fc56655844074b12b.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/16c9ca229c5ce45fc56655844074b12b.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/16c9ca229c5ce45fc56655844074b12b.jpg
#
# 0: 416x512 1 high vegetation, 52.1ms
# Speed: 1.2ms preprocess, 52.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/5f1b97b15cf80c8ff8d8b2866252a09a.jpg
#
# 0: 384x512 1 high vegetation, 51.9ms
# Speed: 1.2ms preprocess, 51.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/3911402727aec44c0a48cf8236c3e5a4.jpg
#
# 0: 480x512 3 high vegetations, 63.9ms
# Speed: 1.2ms preprocess, 63.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/080158528ec8b396365ec05ff3c0e060.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/080158528ec8b396365ec05ff3c0e060.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/080158528ec8b396365ec05ff3c0e060.jpg
#
# 0: 480x512 1 high vegetation, 65.9ms
# Speed: 1.4ms preprocess, 65.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bb58e6a111894edbd9aa9a352de331b2.jpg
# 0: 288x512 3 high vegetations, 46.0ms
# Speed: 0.9ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ba6668a9ca9c1f90c35bbe46011fa441.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ba6668a9ca9c1f90c35bbe46011fa441.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ba6668a9ca9c1f90c35bbe46011fa441.jpg
#
# 0: 512x512 2 high vegetations, 74.2ms
# Speed: 1.3ms preprocess, 74.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/79b38eb421dc65cd791e65f1441a0dac.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/79b38eb421dc65cd791e65f1441a0dac.jpg
#
# 0: 512x512 1 high vegetation, 70.5ms
# Speed: 1.3ms preprocess, 70.5ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/c16525ef4a602bb9b3c3c9a8d785408e.jpg
#
# 0: 480x512 (no detections), 58.8ms
# Speed: 1.3ms preprocess, 58.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/ee1ff350303218023e18223a0f59a4be.jpg
#
# 0: 320x512 1 high vegetation, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/440cdaa6f82b19caa6fd68b49b5513a4.jpg
#
# 0: 416x512 1 high vegetation, 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a53d1286cb195afc65ef79e845635104.jpg
#
# 0: 480x512 1 high vegetation, 56.7ms
# Speed: 1.1ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/43b93d362263f72f31cf2f985894e508.jpg
#
# 0: 416x512 1 high vegetation, 53.2ms
# Speed: 1.1ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/d2055147c2871d3c7138b08d6a87f710.jpg
#
# 0: 480x512 2 high vegetations, 56.4ms
# Speed: 1.3ms preprocess, 56.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/72f1c99e28b2fc8f74df67023ea26cbf.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/72f1c99e28b2fc8f74df67023ea26cbf.jpg
#
# 0: 320x512 2 high vegetations, 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/5e34e7d9e19e07c7ed8a6e9b7b933890.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/5e34e7d9e19e07c7ed8a6e9b7b933890.jpg
#
# 0: 480x512 1 high vegetation, 56.1ms
# Speed: 1.3ms preprocess, 56.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/23cdae522c363b5a29d49bd9911a59d1.jpg
#
# 0: 384x512 (no detections), 50.5ms
# Speed: 0.8ms preprocess, 50.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/c2d11d37823b96f85b5ac84e60153bc5.jpg
#
# 0: 384x512 1 high vegetation, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7bf95c9b0f17ca0bcc29c06a6c7ef826.jpg
#
# 0: 416x512 1 high vegetation, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/5df236169dc4618860b6a86ada986352.jpg
#
# 0: 480x512 1 high vegetation, 58.8ms
# Speed: 1.4ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7548bec38d4b875a87f8fb2ee97c12e9.jpg
#
# 0: 352x512 1 high vegetation, 58.9ms
# Speed: 1.2ms preprocess, 58.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7ea34bab9ff1d71aaca3588b032c348b.jpg
#
# 0: 448x512 1 high vegetation, 71.6ms
# Speed: 1.3ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ed56ae68171ba5ae0c7e67119176e7b9.jpg
#
# 0: 512x512 1 high vegetation, 78.7ms
# Speed: 1.5ms preprocess, 78.7ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/de5abc953073652931cdd5a109fb03cf.jpg
#
# 0: 384x512 2 high vegetations, 57.7ms
# Speed: 1.2ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a31b57ebd8ae61767274993c9cc1d36b.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a31b57ebd8ae61767274993c9cc1d36b.jpg
#
# 0: 416x512 1 high vegetation, 63.0ms
# Speed: 1.2ms preprocess, 63.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/80905ed6ca06075c95e3db7326597afd.jpg
#
# 0: 512x512 1 high vegetation, 78.3ms
# Speed: 1.5ms preprocess, 78.3ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e53421cfd2dafe6d48921b85de05a594.jpg
#
# 0: 448x512 1 high vegetation, 63.5ms
# Speed: 1.3ms preprocess, 63.5ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/94203c03785f4ab78b076853a482bdb9.jpg
#
# 0: 512x512 1 high vegetation, 73.0ms
# Speed: 1.2ms preprocess, 73.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0cd8821db66cf4a8d45413ad6f34b9e8.jpg
#
# 0: 352x512 1 high vegetation, 53.6ms
# Speed: 1.0ms preprocess, 53.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/632fff9859a862ae0f5d8f10db7cf7cd.jpg
#
# 0: 288x512 1 high vegetation, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/9c4dae1ed41673fabf5aff01905e2d20.jpg
#
# 0: 320x512 1 high vegetation, 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/422bb22305ff3bf387b82d85d37b8960.jpg
#
# 0: 416x512 1 high vegetation, 54.1ms
# ...
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6a56e5eb2b5e5d7751085d4d51961316.jpg
#
# 0: 448x512 2 high vegetations, 66.4ms
# Speed: 1.2ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/43b2a1878ab4c466931d14923090ffe3.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/43b2a1878ab4c466931d14923090ffe3.jpg
#
# 0: 384x512 2 high vegetations, 61.7ms
# Speed: 1.1ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b2292f74248ab829e1b421a94bdced55.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b2292f74248ab829e1b421a94bdced55.jpg
#
# 0: 512x512 3 high vegetations, 77.5ms
# Speed: 1.4ms preprocess, 77.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/593aa25e4f14ea29c30f41300e9142c1.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/593aa25e4f14ea29c30f41300e9142c1.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/593aa25e4f14ea29c30f41300e9142c1.jpg
#
# 0: 416x512 2 high vegetations, 66.7ms
# Speed: 1.2ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/d4a0d7f692d2da2d9251fc0345151c4d.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/d4a0d7f692d2da2d9251fc0345151c4d.jpg
#
# 0: 416x512 1 high vegetation, 60.1ms
# Speed: 1.3ms preprocess, 60.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/cc033b54f6550b0778924273a1bec4d2.jpg
#
# 0: 416x512 2 high vegetations, 56.9ms
# Speed: 1.2ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1e9e7ff2a89728a70224f064cb4533fd.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1e9e7ff2a89728a70224f064cb4533fd.jpg
# 0: 384x512 1 high vegetation, 53.5ms
# Speed: 0.8ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/6904d363e76bab08f84c89e8afebf5ea.jpg
#
# 0: 512x512 2 high vegetations, 160.2ms
# Speed: 1.3ms preprocess, 160.2ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/52d0fad3511e997a6a38d01c9063f362.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/52d0fad3511e997a6a38d01c9063f362.jpg
#
# 0: 448x512 1 high vegetation, 64.3ms
# Speed: 1.4ms preprocess, 64.3ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1bac00328715bd89a0f7f37365404a01.jpg
#
# 0: 512x512 1 high vegetation, 76.2ms
# Speed: 1.4ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f38a1792e35e0a5ddcceedb6dfa637d5.jpg
#
# 0: 352x512 2 high vegetations, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ae7dad85ce8e8fc4da29bfe77a4516d0.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ae7dad85ce8e8fc4da29bfe77a4516d0.jpg
#
# 0: 416x512 2 high vegetations, 54.1ms
# Speed: 1.3ms preprocess, 54.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/edfac0c7e2ae0c7e94a03e92d7d4d090.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/edfac0c7e2ae0c7e94a03e92d7d4d090.jpg
#
# 0: 448x512 1 high vegetation, 55.2ms
# Speed: 1.2ms preprocess, 55.2ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/2712d97c3e4dda2ff3668adafe3fe775.jpg
#
# 0: 352x512 2 high vegetations, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0322bff4ce95aee95a8fe70456371b8f.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0322bff4ce95aee95a8fe70456371b8f.jpg
#
# 0: 352x512 1 high vegetation, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a2c4b0cafb32a09361fdb365df505687.jpg
#
# 0: 416x512 1 high vegetation, 58.4ms
# Speed: 1.3ms preprocess, 58.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/01e96c1d38c7b7b4282ca3c9cda2b83b.jpg
#
# 0: 448x512 1 high vegetation, 62.6ms
# Speed: 1.2ms preprocess, 62.6ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/2e401c06a0a21a673a151d5b05a4e1aa.jpg
#
# 0: 416x512 1 high vegetation, 61.0ms
# Speed: 1.2ms preprocess, 61.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7fef69ad990283c9db68b2de61a4eabd.jpg
#
# 0: 416x512 1 high vegetation, 59.7ms
# Speed: 1.2ms preprocess, 59.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/56ba482d41ce26fea0159dea106f9317.jpg
#
# 0: 416x512 1 high vegetation, 65.2ms
# Speed: 1.3ms preprocess, 65.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/9fc345d33a01e1027c759d13768e5aaf.jpg
#
# 0: 416x512 1 high vegetation, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/20052db2d2b1fd325363caee7637341b.jpg
#
# 0: 480x512 1 high vegetation, 60.1ms
# Speed: 1.3ms preprocess, 60.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7a85c551652b50133360413cfa56557e.jpg
#
# 0: 448x512 1 high vegetation, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/cbb52066f3534735fd493f82bc3310a7.jpg
#
# 0: 384x512 3 high vegetations, 61.5ms
# Speed: 1.2ms preprocess, 61.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e525ef922f5a9be5876afa23fc2bbd20.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e525ef922f5a9be5876afa23fc2bbd20.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e525ef922f5a9be5876afa23fc2bbd20.jpg
#
# 0: 416x512 1 high vegetation, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/217b83928af6a2976c2b81002162ca35.jpg
#
# 0: 448x512 2 high vegetations, 63.7ms
# Speed: 1.3ms preprocess, 63.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a99327b04e8ecee2c7d2eca1645f7ee8.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a99327b04e8ecee2c7d2eca1645f7ee8.jpg
#
# 0: 448x512 1 high vegetation, 58.8ms
# Speed: 1.2ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ab04ab6e48eaf0564c3b59881445b4bc.jpg
#
# 0: 448x512 1 high vegetation, 59.0ms
# Speed: 1.3ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a2d9821e96d290c2a18118dd9e6d58ec.jpg
#
# 0: 512x512 1 high vegetation, 71.5ms
# Speed: 1.3ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/7a3384e4dd75375c01680d8867a48909.jpg
#
# 0: 480x512 2 high vegetations, 59.7ms
# Speed: 1.2ms preprocess, 59.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/91f02c059dcbdc5596e9e09f5bcdf4d9.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/91f02c059dcbdc5596e9e09f5bcdf4d9.jpg
#
# 0: 416x512 1 high vegetation, 51.6ms
# Speed: 1.1ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/3da7c621cc5f9b8a8269792bc219f150.jpg
#
# 0: 512x512 1 high vegetation, 68.5ms
# Speed: 1.2ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/0c024f72c6a410cfd4c63b17e967d716.jpg
#
# 0: 512x512 1 high vegetation, 75.9ms
# Speed: 1.4ms preprocess, 75.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/9113ba6237434cadbf9e7c17222dcd1c.jpg
#
# 0: 448x512 2 high vegetations, 65.3ms
# Speed: 1.3ms preprocess, 65.3ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/9abcdf4eefe25493e65b4213110318cf.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/9abcdf4eefe25493e65b4213110318cf.jpg
#
# 0: 384x512 2 high vegetations, 61.3ms
# Speed: 1.1ms preprocess, 61.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b3776e1ce89d2a3d721881a74694d343.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b3776e1ce89d2a3d721881a74694d343.jpg
#
# 0: 512x512 3 high vegetations, 73.7ms
# Speed: 1.3ms preprocess, 73.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/686b2b7dc97d32e1b4607473dbca873b.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/686b2b7dc97d32e1b4607473dbca873b.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/686b2b7dc97d32e1b4607473dbca873b.jpg
# 0: 416x512 1 high vegetation, 56.6ms
# Speed: 1.2ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/60e53e2b00f062bbae6697dbaa6c95e7.jpg
#
# 0: 448x512 1 high vegetation, 61.3ms
# Speed: 1.2ms preprocess, 61.3ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/e8f13a43979343988e1a9f4c79dc5909.jpg
#
# 0: 416x512 1 high vegetation, 56.0ms
# Speed: 1.3ms preprocess, 56.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/2c8e21017e9d92204328beb0839427c5.jpg
#
# 0: 416x512 2 high vegetations, 60.0ms
# Speed: 0.9ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1fe5206e2c08bffb6c42e6cdc4605624.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/1fe5206e2c08bffb6c42e6cdc4605624.jpg
#
# 0: 512x512 1 high vegetation, 72.7ms
# Speed: 1.3ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a42f1d7baa2396a0625fd260aa889595.jpg
#
# 0: 384x512 1 high vegetation, 57.0ms
# Speed: 1.1ms preprocess, 57.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a2724db955364eb1baed0c6b26e17f56.jpg
#
# 0: 416x512 (no detections), 55.5ms
# Speed: 1.2ms preprocess, 55.5ms inference, 0.1ms postprocess per image at shape (1, 3, 416, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/5b18d7adde59e6fe376ab842a50b9f40.jpg
#
# 0: 416x512 1 high vegetation, 59.0ms
# Speed: 1.6ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/86757cdd2449009edf762d1bbf98d853.jpg
#
# 0: 480x512 2 high vegetations, 64.4ms
# Speed: 1.3ms preprocess, 64.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ce30d783ff4d47e1ae4585695ebdc243.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/ce30d783ff4d47e1ae4585695ebdc243.jpg
#
# 0: 416x512 1 high vegetation, 54.4ms
# Speed: 1.5ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/212e0c59ce943360cc783d97a7c1855f.jpg
#
# 0: 416x512 1 high vegetation, 57.8ms
# Speed: 1.3ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/bcb8277bf572fe637e20410ecdb72cc9.jpg
#
# 0: 480x512 1 high vegetation, 62.9ms
# Speed: 1.3ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b14be144c349c2cede8419b3a4882ab1.jpg
#
# 0: 320x512 1 high vegetation, 45.8ms
# Speed: 0.9ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/70297b26b7689ef4e8e010e3736f5f75.jpg
#
# 0: 480x512 2 high vegetations, 67.0ms
# Speed: 1.5ms preprocess, 67.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/2672b778201d194477b99837040408ab.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/2672b778201d194477b99837040408ab.jpg
#
# 0: 352x512 1 high vegetation, 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a6b6c0a08c6a4f48d55d81b0f1da1d05.jpg
#
# 0: 384x512 2 high vegetations, 58.6ms
# Speed: 1.0ms preprocess, 58.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f4a356438f87cba5b569cc33e32a41f0.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/f4a356438f87cba5b569cc33e32a41f0.jpg
#
# 0: 480x512 1 high vegetation, 62.6ms
# Speed: 1.4ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b2ca2e383a24e9c082ccbba3f0daa499.jpg
#
# 0: 448x512 2 high vegetations, 61.5ms
# Speed: 1.1ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a597a13ea60dcb4469a9d2a235c2855a.jpg
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/a597a13ea60dcb4469a9d2a235c2855a.jpg
#
# 0: 512x512 (no detections), 70.4ms
# Speed: 1.5ms preprocess, 70.4ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 512)
# No masks found for: /Users/vaishalilalit/Downloads/train/test/mask/5186f5bbe054ddb4ddd877d3d27209c7.jpg
#
# 0: 448x512 1 high vegetation, 57.8ms
# Speed: 1.3ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/fe2d29826912e1bc1aa753a41b8d2ee5.jpg
#
# 0: 512x512 1 high vegetation, 69.2ms
# Speed: 1.4ms preprocess, 69.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/27a0f85d3d8218bb71c63c26700b9e2e.jpg
#
# 0: 384x512 1 high vegetation, 53.8ms
# Speed: 1.0ms preprocess, 53.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 512)
# Saved mask at: /Users/vaishalilalit/Downloads/train/test/mask/b63cb3795248785ea4d59a949adae0fa.jpg

# %%
# cd '/Users/vaishalilalit/Downloads/train2/Mynewtest/train'

# %%
# pip install py-cpuinfo

# %%
import shutil
import os
source_folder = '/Users/vaishalilalit/Downloads/train/test/test'
target_folder = '/Users/vaishalilalit/Downloads/train/test/mask'


source_images = set(os.path.splitext(image)[0] for image in os.listdir(source_folder))
target_images = set(os.path.splitext(image)[0] for image in os.listdir(target_folder))

print('Number of source images:', len(source_images))
print('Number of target images:', len(target_images))

images_to_delete = source_images - target_images
print('difference images',len(images_to_delete))
for image_name in images_to_delete:
     source_path = os.path.join('/Users/vaishalilalit/Downloads/train/test/test', image_name+ '.jpg')
     destination_path = os.path.join('/Users/vaishalilalit/Downloads/train/test/untest', image_name+ '.jpg')

#         # Move the image to the destination folder
     shutil.move(source_path, destination_path)
     print(f"Moved: {source_path} to {destination_path}")
# Out:
# Number of source images: 783
# Number of target images: 760
# difference images 24
# Moved: /Users/vaishalilalit/Downloads/train/test/test/5e15ceb87b534a7773919566a6674fa3.jpg to /Users/vaishalilalit/Downloads/train/test/untest/5e15ceb87b534a7773919566a6674fa3.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/28391df6208f458f56f8f347d03b2e0f.jpg to /Users/vaishalilalit/Downloads/train/test/untest/28391df6208f458f56f8f347d03b2e0f.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/3ec60e6b8b3f48261966e7ca6881195d.jpg to /Users/vaishalilalit/Downloads/train/test/untest/3ec60e6b8b3f48261966e7ca6881195d.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/0baec17c62666d572fe5d2c047d058fe.jpg to /Users/vaishalilalit/Downloads/train/test/untest/0baec17c62666d572fe5d2c047d058fe.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/7337cc1f7c921640145088a26e6d6e3c.jpg to /Users/vaishalilalit/Downloads/train/test/untest/7337cc1f7c921640145088a26e6d6e3c.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/b6b18e022c136c239887b31eccb4f52c.jpg to /Users/vaishalilalit/Downloads/train/test/untest/b6b18e022c136c239887b31eccb4f52c.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/ee1ff350303218023e18223a0f59a4be.jpg to /Users/vaishalilalit/Downloads/train/test/untest/ee1ff350303218023e18223a0f59a4be.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/d4b5777f7af47b867c353f182c1b9923.jpg to /Users/vaishalilalit/Downloads/train/test/untest/d4b5777f7af47b867c353f182c1b9923.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/12b0f4865049468d027314c06ce49ff3.jpg to /Users/vaishalilalit/Downloads/train/test/untest/12b0f4865049468d027314c06ce49ff3.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/0b3006c1c2db96503bf111735e63d691.jpg to /Users/vaishalilalit/Downloads/train/test/untest/0b3006c1c2db96503bf111735e63d691.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/3ff389564efaa89732a5cfb5531d654e.jpg to /Users/vaishalilalit/Downloads/train/test/untest/3ff389564efaa89732a5cfb5531d654e.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/10dbb702be37ca54bbc43d394f84296b.jpg to /Users/vaishalilalit/Downloads/train/test/untest/10dbb702be37ca54bbc43d394f84296b.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/5186f5bbe054ddb4ddd877d3d27209c7.jpg to /Users/vaishalilalit/Downloads/train/test/untest/5186f5bbe054ddb4ddd877d3d27209c7.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/ef63ace48c1d465080c727005c5097b1.jpg to /Users/vaishalilalit/Downloads/train/test/untest/ef63ace48c1d465080c727005c5097b1.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/2d1a84b127fcac7bbeb5e3d6b71e8db1.jpg to /Users/vaishalilalit/Downloads/train/test/untest/2d1a84b127fcac7bbeb5e3d6b71e8db1.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/f2aa092b90a9e20f2c5b25d5232945ed.jpg to /Users/vaishalilalit/Downloads/train/test/untest/f2aa092b90a9e20f2c5b25d5232945ed.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/a9ece6350d46dcb59bc7c78162c4b872.jpg to /Users/vaishalilalit/Downloads/train/test/untest/a9ece6350d46dcb59bc7c78162c4b872.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/06f4f690a4386fcb2fcde4323fb90c61.jpg to /Users/vaishalilalit/Downloads/train/test/untest/06f4f690a4386fcb2fcde4323fb90c61.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/c2d11d37823b96f85b5ac84e60153bc5.jpg to /Users/vaishalilalit/Downloads/train/test/untest/c2d11d37823b96f85b5ac84e60153bc5.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/162bb1002b6ebfdb2a7df3f6deb308d7.jpg to /Users/vaishalilalit/Downloads/train/test/untest/162bb1002b6ebfdb2a7df3f6deb308d7.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/71fc5dcfd7b57ae37c29a713033bf285.jpg to /Users/vaishalilalit/Downloads/train/test/untest/71fc5dcfd7b57ae37c29a713033bf285.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/2f1b25325b29f7e837bb2bc4b7c9b44a.jpg to /Users/vaishalilalit/Downloads/train/test/untest/2f1b25325b29f7e837bb2bc4b7c9b44a.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/fd621ffbdded40d07b2a82f9cae267b1.jpg to /Users/vaishalilalit/Downloads/train/test/untest/fd621ffbdded40d07b2a82f9cae267b1.jpg
# Moved: /Users/vaishalilalit/Downloads/train/test/test/5b18d7adde59e6fe376ab842a50b9f40.jpg to /Users/vaishalilalit/Downloads/train/test/untest/5b18d7adde59e6fe376ab842a50b9f40.jpg

# %%
import numpy as np
input_folder='/Users/vaishalilalit/Downloads/train/test/untest'
output_folder='/Users/vaishalilalit/Downloads/train/test/mask1'
for filename in os.listdir(input_folder):
            # Read the image to get its dimensions
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)
        height, width, _ = image.shape

            # Create a black image with the same dimensions as the original image
        black_mask = np.zeros((height, width), dtype=np.uint8)

            # Save the black mask with the same filename in the output folder
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, black_mask)

        print(f"Generated black mask for {filename}")
# Out:
# Generated black mask for 3ec60e6b8b3f48261966e7ca6881195d.jpg
# Generated black mask for b6b18e022c136c239887b31eccb4f52c.jpg
# Generated black mask for 0baec17c62666d572fe5d2c047d058fe.jpg
# Generated black mask for 5e15ceb87b534a7773919566a6674fa3.jpg
# Generated black mask for 12b0f4865049468d027314c06ce49ff3.jpg
# Generated black mask for a9ece6350d46dcb59bc7c78162c4b872.jpg
# Generated black mask for ee1ff350303218023e18223a0f59a4be.jpg
# Generated black mask for c2d11d37823b96f85b5ac84e60153bc5.jpg
# Generated black mask for 71fc5dcfd7b57ae37c29a713033bf285.jpg
# Generated black mask for 06f4f690a4386fcb2fcde4323fb90c61.jpg
# Generated black mask for 3ff389564efaa89732a5cfb5531d654e.jpg
# Generated black mask for 2d1a84b127fcac7bbeb5e3d6b71e8db1.jpg
# Generated black mask for 162bb1002b6ebfdb2a7df3f6deb308d7.jpg
# Generated black mask for 28391df6208f458f56f8f347d03b2e0f.jpg
# Generated black mask for ef63ace48c1d465080c727005c5097b1.jpg
# Generated black mask for 0b3006c1c2db96503bf111735e63d691.jpg
# Generated black mask for d4b5777f7af47b867c353f182c1b9923.jpg
# Generated black mask for 7337cc1f7c921640145088a26e6d6e3c.jpg
# Generated black mask for 2f1b25325b29f7e837bb2bc4b7c9b44a.jpg
# Generated black mask for f2aa092b90a9e20f2c5b25d5232945ed.jpg
# Generated black mask for fd621ffbdded40d07b2a82f9cae267b1.jpg
# Generated black mask for 10dbb702be37ca54bbc43d394f84296b.jpg
# Generated black mask for 5b18d7adde59e6fe376ab842a50b9f40.jpg
# Generated black mask for 5186f5bbe054ddb4ddd877d3d27209c7.jpg

# %%
import json
import numpy as np
import os
from PIL import Image
all_dict = {}
for file_name in os.listdir(r'/Users/vaishalilalit/Downloads/train/test/mask'):
    temp_dict = {}
    image = Image.open(r'/Users/vaishalilalit/Downloads/train/test/mask/' + file_name)
    # with open(r'D:\College\External Project\UCC\Data\train2\train2\test\mask\\test.txt','w') as f:
    #     for i in range(0, image.size[0]):
    #         for j in range(0, image.size[1]):
    #             f.write(str(image.getpixel((i,j))))
    #             f.write('\n')
    #     f.write(str(np.array(image).flatten()))
    # # print(np.array(image))
    # break
    new_array = np.array(image)/255
    new_array = new_array.astype(int)
    temp_dict["counts"] = mask_to_rle(new_array)

    temp_dict["height"] = image.size[1]
    temp_dict["width"] = image.size[0]
    all_dict[file_name] = temp_dict
    # break
json_obj = json.dumps(all_dict)

with open(r'/Users/vaishalilalit/Downloads/train/test/results.json', 'w') as f:
    f.write(json_obj)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[46], line 8
#       6 for file_name in os.listdir(r'/Users/vaishalilalit/Downloads/train/test/mask'):
#       7     temp_dict = {}
# ----> 8     image = Image.open(r'/Users/vaishalilalit/Downloads/train/test/mask/' + file_name)
#       9     # with open(r'D:\College\External Project\UCC\Data\train2\train2\test\mask\\test.txt','w') as f:
#      10     #     for i in range(0, image.size[0]):
#      11     #         for j in range(0, image.size[1]):
#    (...)
#      15     # # print(np.array(image))
#      16     # break
#      17     new_array = np.array(image)/255
#
# File ~/anaconda3/lib/python3.11/site-packages/PIL/Image.py:3283, in open(fp, mode, formats)
#    3281     warnings.warn(message)
#    3282 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3283 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file '/Users/vaishalilalit/Downloads/train/test/mask/.DS_Store'

# %%
import json
import numpy as np
import os
from PIL import Image

# List of supported image file extensions
image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif']

all_dict = {}

folder_path = '/Users/vaishalilalit/Downloads/train/test/mask'

for file_name in os.listdir(folder_path):
    if any(file_name.lower().endswith(ext) for ext in image_extensions):
        temp_dict = {}
        image_path = os.path.join(folder_path, file_name)
        image = Image.open(image_path)
        
        # Perform image processing or other operations here
        new_array = np.array(image) / 255
        new_array = new_array.astype(int)
        
        temp_dict["counts"] = mask_to_rle(new_array)
        temp_dict["height"] = image.size[1]
        temp_dict["width"] = image.size[0]
        all_dict[file_name] = temp_dict

# Convert dictionary to JSON string
json_obj = json.dumps(all_dict)

# Write JSON string to a file
with open('/Users/vaishalilalit/Downloads/train/test/results.json', 'w') as f:
    f.write(json_obj)

# %%
def mask_to_rle(mask: np.ndarray):
    """
    Convert a binary mask to RLE format.
    :param mask: numpy array, 1 - mask, 0 - background
    :return: RLE array
    """
    pixels = mask.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return [int(x) for x in runs]
